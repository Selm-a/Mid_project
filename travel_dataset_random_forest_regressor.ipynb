# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/Selma/Desktop/Ironhack/labs/MID PROJECT/travel_dataset_cleaned.csv")
df
# Out:
#      Unnamed: 0  Destination  Duration (days)  Traveler age Traveler gender  \
# 0             0           UK              7.0          35.0            Male
# 1             1     Thailand              5.0          28.0          Female
# 2             2    Indonesia              7.0          45.0            Male
# 3             3          USA             14.0          29.0          Female
# 4             4        Japan              7.0          26.0          Female
# ..          ...          ...              ...           ...             ...
# 131         134       Brazil              9.0          37.0            Male
# 132         135       Canada              6.0          29.0          Female
# 133         136     Thailand              7.0          34.0            Male
# 134         137        Spain              7.0          25.0          Female
# 135         138  New Zealand              7.0          39.0            Male
#
#     Traveler nationality Accommodation type  Accommodation cost  \
# 0            US American              Hotel                1200
# 1               Canadian        Luxury stay                 800
# 2                 Korean        Luxury stay                1000
# 3                     UK              Hotel                2000
# 4             Vietnamese             Airbnb                 700
# ..                   ...                ...                 ...
# 131            Brazilian             Hostel                2500
# 132             Canadian              Hotel                5000
# 133              Chinese             Hostel                2000
# 134              Spanish             Airbnb                6000
# 135        New Zealander              Hotel                7000
#
#     Transportation type  Transportation cost Age range Destination Region  \
# 0              Airplane                  600   32 - 37             Europe
# 1              Airplane                  500   20 - 28             Africa
# 2              Airplane                  700      38 +               Asia
# 3              Airplane                 1000   29 - 31      North America
# 4                 Train                  200   20 - 28               Asia
# ..                  ...                  ...       ...                ...
# 131                 Car                 2000   32 - 37      South America
# 132            Airplane                 3000   29 - 31      North America
# 133               Train                 1000   32 - 37             Africa
# 134            Airplane                 2500   20 - 28             Europe
# 135               Train                 2500      38 +               Asia
#
#     Traveler Region  Trip month  Total cost       Budget
# 0     North America           5        1800  medium high
# 1     North America           6        1300   medium low
# 2              Asia           7        1700  medium high
# 3            Europe           8        3000         high
# 4              Asia           9         900   medium low
# ..              ...         ...         ...          ...
# 131   South America           8        4500         high
# 132   North America           8        8000         high
# 133            Asia           9        3000         high
# 134          Europe           9        8500         high
# 135            Asia          10        9500         high
#
# [136 rows x 16 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.columns
# Out:
# Index(['Destination', 'Duration (days)', 'Traveler age', 'Traveler gender',
#        'Traveler nationality', 'Accommodation type', 'Accommodation cost',
#        'Transportation type', 'Transportation cost', 'Age range',
#        'Destination Region', 'Traveler Region', 'Trip month', 'Total cost',
#        'Budget'],
#       dtype='object')

# %%
X = df.drop(['Destination', 'Duration (days)', 'Traveler age','Traveler nationality', 'Accommodation type','Transportation type', 'Traveler Region', 'Trip month', 'Total cost'], axis=1)
X
# Out:
#     Traveler gender  Accommodation cost  Transportation cost Age range  \
# 0              Male                1200                  600   32 - 37
# 1            Female                 800                  500   20 - 28
# 2              Male                1000                  700      38 +
# 3            Female                2000                 1000   29 - 31
# 4            Female                 700                  200   20 - 28
# ..              ...                 ...                  ...       ...
# 131            Male                2500                 2000   32 - 37
# 132          Female                5000                 3000   29 - 31
# 133            Male                2000                 1000   32 - 37
# 134          Female                6000                 2500   20 - 28
# 135            Male                7000                 2500      38 +
#
#     Destination Region       Budget
# 0               Europe  medium high
# 1               Africa   medium low
# 2                 Asia  medium high
# 3        North America         high
# 4                 Asia   medium low
# ..                 ...          ...
# 131      South America         high
# 132      North America         high
# 133             Africa         high
# 134             Europe         high
# 135               Asia         high
#
# [136 rows x 6 columns]

# %%
y = df.drop(['Destination', 'Duration (days)', 'Traveler age', 'Traveler gender',
       'Traveler nationality', 'Accommodation type', 'Accommodation cost',
       'Transportation type', 'Transportation cost', 'Age range',
       'Destination Region', 'Traveler Region', 'Trip month','Budget'], axis=1)

y
# Out:
#      Total cost
# 0          1800
# 1          1300
# 2          1700
# 3          3000
# 4           900
# ..          ...
# 131        4500
# 132        8000
# 133        3000
# 134        8500
# 135        9500
#
# [136 rows x 1 columns]

# %%
X.columns
# Out:
# Index(['Traveler gender', 'Accommodation cost', 'Transportation cost',
#        'Age range', 'Destination Region', 'Budget'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
 
label_encoder = LabelEncoder()
X_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
X_numerical = df.select_dtypes(exclude=['object']).values
X = pd.concat([pd.DataFrame(X_numerical), X_categorical], axis=1).values
 
# Fitting Random Forest Regression to the dataset
regressor = RandomForestRegressor(n_estimators=50, random_state=0, oob_score=True)
 
# Fit the regressor with x and y data
regressor.fit(X, y)
# Out:
# C:\Users\Selma\AppData\Local\Temp\ipykernel_6328\3082972249.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X, y)
# RandomForestRegressor(n_estimators=50, oob_score=True, random_state=0)

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score
 
# Access the OOB Score
oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')
 
# Making predictions on the same data or new data
predictions = regressor.predict(X)
 
# Evaluating the model
mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')
 
r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.976493448045542
# Mean Squared Error: 9864.29132352941
# R-squared: 0.9970473616827076

# %%
selected_feat= X.columns[(sel.get_support())]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 selected_feat= X.columns[(sel.get_support())]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
## rank of the features

feature_importance = pd.DataFrame({"features": selected_feat,
                                  "weights": regressor.feature_importance_}) 

feature_importance.sort_values(by = "weights", ascending =False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## rank of the features
# ----> 3 feature_importance = pd.DataFrame({"features": X.columns,
#       4                                   "weights": regressor.feature_importance_})
#       6 feature_importance.sort_values(by = "weights", ascending =False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
